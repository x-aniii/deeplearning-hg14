# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/hg14-handgesture14-dataset/HG14/Read.docx
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11925.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11378.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11138.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11868.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11034.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11251.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11617.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11921.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11236.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11522.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11529.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11956.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11684.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11855.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11901.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11382.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11087.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11848.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11682.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11428.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11058.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11849.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11690.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11524.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11895.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11024.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11641.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11265.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11751.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11452.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11422.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11678.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11321.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11153.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11774.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11763.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11882.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11619.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11106.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11397.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11550.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11784.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11514.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11756.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11552.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11926.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11649.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11729.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11430.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11746.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11099.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11001.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11278.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11245.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11272.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11054.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11677.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11412.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11096.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11792.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11821.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11449.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11354.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11584.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11021.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11703.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11534.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11799.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11051.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11122.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11609.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11443.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11062.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11399.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11456.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11807.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11425.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11854.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11318.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11798.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11794.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11098.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11509.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11771.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11576.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11670.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11294.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11979.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11162.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11846.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11002.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11813.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11640.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11074.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11759.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11898.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11749.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11837.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11313.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11567.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11280.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11402.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11795.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11958.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11500.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11789.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11184.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11168.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11004.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11800.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11775.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11928.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11434.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11716.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11501.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11163.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11464.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11625.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11110.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11704.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11736.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11288.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11648.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11339.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11917.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11965.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11535.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11857.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11660.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11343.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11427.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11348.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11140.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11441.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11708.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11510.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11549.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11505.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11388.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11264.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11079.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11226.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11720.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11700.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11387.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11372.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11820.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11831.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11512.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11859.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11922.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11308.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11740.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11486.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11403.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11471.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11389.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11566.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11804.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11421.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11913.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11187.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11223.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11336.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11109.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11126.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11561.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11253.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11446.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11274.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11876.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11252.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11916.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11568.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11174.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11503.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11439.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11906.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11193.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11952.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11969.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11191.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11055.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11528.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11466.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11142.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11879.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11739.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11527.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11076.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11467.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11338.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11323.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11183.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11770.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11735.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11222.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11275.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11899.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11295.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11652.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11475.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11023.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11210.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11806.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11290.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11827.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11546.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11892.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11225.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11082.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11886.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11689.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11032.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11542.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11631.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11310.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11933.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11997.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11164.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11363.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11487.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11773.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11818.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11779.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11551.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11573.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11548.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11873.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11344.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11052.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11292.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11662.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11463.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11063.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11554.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11312.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11101.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11282.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11075.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11247.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11248.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11828.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11018.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11218.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11605.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11249.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11981.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11356.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11569.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11734.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11699.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11419.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11392.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11353.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11496.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11681.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11880.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11172.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11629.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11702.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11996.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11064.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11141.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11469.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11900.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11160.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11291.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11081.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11067.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11042.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11582.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11829.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11823.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11041.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11553.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11373.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11022.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11072.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11093.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11263.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11201.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11885.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11611.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11571.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11788.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11588.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11207.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11646.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11695.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11903.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11537.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11521.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11405.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11221.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11136.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11517.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11980.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11238.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11686.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11048.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11968.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11998.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11889.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11233.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11947.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11663.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11476.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11639.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11112.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11448.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11155.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11832.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11302.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11777.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11019.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11334.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11819.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11856.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11038.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11714.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11613.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11182.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11531.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11420.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11853.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11772.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11407.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11755.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11719.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11814.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11445.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11722.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11747.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11088.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11993.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11243.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11385.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11224.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11121.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11120.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11314.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11270.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11673.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11131.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11659.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11994.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11768.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11769.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11231.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11304.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11574.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11139.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11816.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11352.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11125.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11508.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11259.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11875.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11398.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11502.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11029.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11540.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11346.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11485.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11473.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11579.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11999.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11715.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11847.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11315.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11499.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11011.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11129.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11656.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11188.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11825.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11844.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11738.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11196.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11215.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11078.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11940.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11057.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11805.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11383.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11261.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11737.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11841.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11037.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11732.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11742.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11937.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11633.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11727.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11460.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11705.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11150.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11978.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11049.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11802.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11801.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11557.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11271.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11745.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11867.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11169.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11711.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11345.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11242.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11173.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11254.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11602.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11045.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11638.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11612.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11556.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11133.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11666.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11377.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11128.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11538.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11706.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11766.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11545.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11080.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11458.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11963.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11013.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11927.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11384.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11404.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11931.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11614.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11634.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11301.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11492.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11544.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11107.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11725.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11606.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11526.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11694.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11365.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11491.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11065.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11907.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11511.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11982.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11624.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11276.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11381.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11119.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11948.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11040.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11256.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11836.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11014.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11976.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11939.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11192.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11583.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11726.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11474.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11347.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11097.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11432.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11974.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11257.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11331.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11752.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11027.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11912.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11123.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11299.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11896.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11897.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11585.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11050.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11429.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11596.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11156.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11031.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11333.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11908.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11787.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11863.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11635.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11790.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11105.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11941.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11810.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11229.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11600.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11426.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11890.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11359.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11599.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11361.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11442.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11570.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11971.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11586.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11012.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11713.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11103.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11949.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11826.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11197.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11894.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11781.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11198.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11616.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11190.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11642.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11603.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11144.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11073.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11017.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11203.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11504.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11497.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11396.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11533.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11778.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11764.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11620.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11158.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11061.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11214.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11644.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11870.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11547.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11966.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11758.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11595.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11610.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11762.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11655.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11701.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11887.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11498.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11216.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11143.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11461.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11212.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11342.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11607.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11391.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11753.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11084.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11793.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11089.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11891.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11712.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11281.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11176.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11930.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11220.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11208.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11973.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11860.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11177.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_11/11647.jpg
# ...
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13757.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13755.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13119.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13649.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13917.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13711.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13045.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13639.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13674.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13645.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13039.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13736.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13959.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13132.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13434.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13976.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13155.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13569.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13219.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13663.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13329.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13171.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13486.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13551.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13536.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13604.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13477.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13721.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13230.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13191.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13874.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13780.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13144.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13698.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13176.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13724.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13415.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13904.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13438.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13361.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13172.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13036.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13452.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13915.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13583.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13995.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13643.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13654.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13211.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13466.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13557.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13540.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13925.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13034.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13715.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13838.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13690.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13814.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13805.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13245.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13207.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13835.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13483.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13826.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13323.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13582.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13150.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13504.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13731.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13088.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13765.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13564.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13989.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13487.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13064.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13947.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13280.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13113.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13165.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13011.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13791.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13776.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13356.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13381.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13777.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13411.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13019.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13954.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13081.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13459.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13302.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13825.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13517.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13618.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13631.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13242.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13702.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13149.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13533.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13026.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13628.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13475.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13299.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13938.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13454.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13681.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13806.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13655.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13758.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13484.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13990.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13794.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13403.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13796.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13285.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13187.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13563.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13577.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13471.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13591.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13783.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13786.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13104.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13214.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13167.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13398.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13669.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13375.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13012.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13474.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13460.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13263.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13335.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13063.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13481.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13154.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13493.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13013.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13109.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13037.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13096.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13384.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13687.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13440.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13152.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13426.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13275.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13089.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13141.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13404.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13522.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13326.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13668.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13778.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13548.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13718.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13189.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13578.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13937.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13256.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13800.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13282.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13399.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13760.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13015.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13342.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13350.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13418.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13652.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13070.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13885.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13705.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13756.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13161.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13083.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13320.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13971.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13319.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13327.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13136.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13510.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13576.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13286.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13140.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13307.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13900.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13114.jpg
# /kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/Gesture_13/13877.jpg

# %% [markdown]
# # 1. ResNet-50 Model

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
def load_images_kaggle():
    images = []
    labels = []

    root_path = '/kaggle/input/hg14-handgesture14-dataset/HG14/'

    for label in range(14):  
        gesture_folder = f'Gesture_{label}'
        gesture_path = os.path.join(root_path, 'HG14-Hand Gesture', gesture_folder)
        
        for dirname, _, filenames in os.walk(gesture_path):
            for filename in filenames:
                if filename.endswith('.jpg'):  
                    filepath = os.path.join(dirname, filename)
                    images.append(filepath)
                    labels.append(label)

    data = pd.DataFrame({'Image': images, 'Label': labels})
    return data

# %%
data = load_images_kaggle()

# %%
train_df, val_df = train_test_split(data, test_size=0.2, random_state=2024)

# %%
def preprocess_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224))  
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img

# %%
def create_dataset(df, batch_size=32):
    image_paths = df['Image'].values
    labels = df['Label'].values

    image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    image_dataset = image_dataset.map(preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    label_dataset = tf.data.Dataset.from_tensor_slices(labels)

    dataset = tf.data.Dataset.zip((image_dataset, label_dataset))
    dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
batch_size = 32
train_dataset = create_dataset(train_df, batch_size=batch_size)
val_dataset = create_dataset(val_df, batch_size=batch_size)

# %%
resnet50 = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
for layer in resnet50.layers:
    layer.trainable = False

model = models.Sequential([
    resnet50,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dense(14, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
epochs = 10
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset)
# Out:
# Epoch 1/10
#   2/350 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.1328 - loss: 3.0080
# W0000 00:00:1710691019.817902     160 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5758 - loss: 1.3231
# W0000 00:00:1710691057.530276     160 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 79s 134ms/step - accuracy: 0.5762 - loss: 1.3217 - val_accuracy: 0.8775 - val_loss: 0.3438
# Epoch 2/10
# W0000 00:00:1710691066.551900     159 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9086 - loss: 0.2744 - val_accuracy: 0.9057 - val_loss: 0.2628
# Epoch 3/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9463 - loss: 0.1686 - val_accuracy: 0.9150 - val_loss: 0.2216
# Epoch 4/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 117ms/step - accuracy: 0.9607 - loss: 0.1162 - val_accuracy: 0.9432 - val_loss: 0.1679
# Epoch 5/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 116ms/step - accuracy: 0.9767 - loss: 0.0787 - val_accuracy: 0.9454 - val_loss: 0.1537
# Epoch 6/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9771 - loss: 0.0721 - val_accuracy: 0.9536 - val_loss: 0.1420
# Epoch 7/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9781 - loss: 0.0676 - val_accuracy: 0.9296 - val_loss: 0.2019
# Epoch 8/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9747 - loss: 0.0704 - val_accuracy: 0.9589 - val_loss: 0.1195
# Epoch 9/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 116ms/step - accuracy: 0.9831 - loss: 0.0532 - val_accuracy: 0.9479 - val_loss: 0.1424
# Epoch 10/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 59s 120ms/step - accuracy: 0.9810 - loss: 0.0525 - val_accuracy: 0.9475 - val_loss: 0.1753

# %%
val_loss, val_accuracy = model.evaluate(val_dataset)
formatted_accuracy = "{:.2f}%".format(val_accuracy * 100)
print("Accuracy on validation set:", formatted_accuracy)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.9503 - loss: 0.1560
# Accuracy on validation set: 94.75%

# %% [markdown]
# # 2. Improving Model Performance

# %% [markdown]
# ## 2.1 Data Augmentation

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

# %%
def load_images_kaggle():
    images = []
    labels = []

    root_path = '/kaggle/input/hg14-handgesture14-dataset/HG14/'

    for label in range(14):  
        gesture_folder = f'Gesture_{label}'
        gesture_path = os.path.join(root_path, 'HG14-Hand Gesture', gesture_folder)
        
        for dirname, _, filenames in os.walk(gesture_path):
            for filename in filenames:
                if filename.endswith('.jpg'):  
                    filepath = os.path.join(dirname, filename)
                    images.append(filepath)
                    labels.append(label)

    data = pd.DataFrame({'Image': images, 'Label': labels})
    return data

# %%
data = load_images_kaggle()

# %%
train_df, val_df = train_test_split(data, test_size=0.2, random_state=2024)

# %%
def preprocess_image(image):
    image = tf.image.resize(image, (224, 224)) 
    image = tf.keras.applications.resnet50.preprocess_input(image)
    return image

# %%
def create_dataset(df, batch_size=32, augment=False):
    image_paths = df['Image'].values
    labels = df['Label'].values

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(lambda x, y: (tf.io.read_file(x), y))

    def decode_and_preprocess_image(image, label):
        image = tf.image.decode_jpeg(image, channels=3)
        image = preprocess_image(image)
        return image, label
    
    dataset = dataset.map(decode_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    
    if augment:
        data_augmentation = tf.keras.Sequential([
            tf.keras.layers.RandomRotation(0.2),
            tf.keras.layers.RandomZoom(0.2),
            tf.keras.layers.RandomFlip("horizontal"),
            tf.keras.layers.RandomContrast(0.2),
        ])
        dataset = dataset.map(lambda x, y: (data_augmentation(x, training=True), y),
                              num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
batch_size = 32
train_dataset = create_dataset(train_df, batch_size=batch_size, augment=True)  
val_dataset = create_dataset(val_df, batch_size=batch_size)

# %%
resnet50 = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
for layer in resnet50.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model_augment = models.Sequential([
    resnet50,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dense(14, activation='softmax')
])

# %%
model_augment.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
epochs = 10
history = model_augment.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset)
# Out:
# Epoch 1/10
#   1/350 ━━━━━━━━━━━━━━━━━━━━ 9:40:23 100s/step - accuracy: 0.0625 - loss: 2.9951
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710688835.561471     158 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710688835.617332     158 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4718 - loss: 1.6071
# W0000 00:00:1710688876.284895     158 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 153s 153ms/step - accuracy: 0.4721 - loss: 1.6059 - val_accuracy: 0.6896 - val_loss: 0.8609
# Epoch 2/10
# W0000 00:00:1710688889.246467     157 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 111s 115ms/step - accuracy: 0.7389 - loss: 0.7227 - val_accuracy: 0.7532 - val_loss: 0.7046
# Epoch 3/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 110s 116ms/step - accuracy: 0.7871 - loss: 0.5823 - val_accuracy: 0.7200 - val_loss: 0.7778
# Epoch 4/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 111s 117ms/step - accuracy: 0.8132 - loss: 0.5168 - val_accuracy: 0.7554 - val_loss: 0.6748
# Epoch 5/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 111s 116ms/step - accuracy: 0.8328 - loss: 0.4636 - val_accuracy: 0.7936 - val_loss: 0.5626
# Epoch 6/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 110s 116ms/step - accuracy: 0.8502 - loss: 0.4148 - val_accuracy: 0.7568 - val_loss: 0.7184
# Epoch 7/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 109s 114ms/step - accuracy: 0.8495 - loss: 0.4065 - val_accuracy: 0.8068 - val_loss: 0.5715
# Epoch 8/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 110s 116ms/step - accuracy: 0.8624 - loss: 0.3699 - val_accuracy: 0.7732 - val_loss: 0.7024
# Epoch 9/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 111s 115ms/step - accuracy: 0.8675 - loss: 0.3699 - val_accuracy: 0.7643 - val_loss: 0.7092
# Epoch 10/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 111s 116ms/step - accuracy: 0.8743 - loss: 0.3479 - val_accuracy: 0.8229 - val_loss: 0.5128

# %%
val_loss, val_accuracy = model_augment.evaluate(val_dataset)
formatted_accuracy = "{:.2f}%".format(val_accuracy * 100)
print("Accuracy on validation set after data augmentation:", formatted_accuracy)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8168 - loss: 0.5133
# Accuracy on validation set after data augmentation: 82.29%

# %% [markdown]
# ## 2.2 Transfer Learning

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split

# %%
def load_images_kaggle():
    images = []
    labels = []

    root_path = '/kaggle/input/hg14-handgesture14-dataset/HG14/'

    for label in range(14):  
        gesture_folder = f'Gesture_{label}'
        gesture_path = os.path.join(root_path, 'HG14-Hand Gesture', gesture_folder)
        
        for dirname, _, filenames in os.walk(gesture_path):
            for filename in filenames:
                if filename.endswith('.jpg'):  
                    filepath = os.path.join(dirname, filename)
                    images.append(filepath)
                    labels.append(label)

    data = pd.DataFrame({'Image': images, 'Label': labels})
    return data

# %%
data = load_images_kaggle()

# %%
train_df, val_df = train_test_split(data, test_size=0.2, random_state=2024)

# %%
def preprocess_image(image):
    image = tf.image.resize(image, (224, 224))  
    image = tf.keras.applications.resnet50.preprocess_input(image)
    return image

# %%
def create_dataset(df, batch_size=32):
    image_paths = df['Image'].values
    labels = df['Label'].values

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(lambda x, y: (tf.io.read_file(x), y))

    def decode_and_preprocess_image(image, label):
        image = tf.image.decode_jpeg(image, channels=3)
        image = preprocess_image(image)
        return image, label
    
    dataset = dataset.map(decode_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
batch_size = 32
train_dataset = create_dataset(train_df, batch_size=batch_size)
val_dataset = create_dataset(val_df, batch_size=batch_size)

# %%
resnet50_base = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
for layer in resnet50_base.layers:
    layer.trainable = False

# %%
transfer_model = models.Sequential([
    resnet50_base,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dense(14, activation='softmax')
])

# %%
transfer_model.compile(optimizer='adam',
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
epochs = 10
history = transfer_model.fit(train_dataset,
                             epochs=epochs,
                             validation_data=val_dataset)
# Out:
# Epoch 1/10
#   2/350 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.1016 - loss: 3.4744
# W0000 00:00:1710662581.549433      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5582 - loss: 1.4362
# W0000 00:00:1710662618.696957      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 73s 131ms/step - accuracy: 0.5587 - loss: 1.4346 - val_accuracy: 0.8546 - val_loss: 0.4016
# Epoch 2/10
# W0000 00:00:1710662627.468156      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.8999 - loss: 0.2966 - val_accuracy: 0.8918 - val_loss: 0.3015
# Epoch 3/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9546 - loss: 0.1566 - val_accuracy: 0.9211 - val_loss: 0.2214
# Epoch 4/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9614 - loss: 0.1149 - val_accuracy: 0.9414 - val_loss: 0.1665
# Epoch 5/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9754 - loss: 0.0827 - val_accuracy: 0.9468 - val_loss: 0.1514
# Epoch 6/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 116ms/step - accuracy: 0.9790 - loss: 0.0676 - val_accuracy: 0.9546 - val_loss: 0.1405
# Epoch 7/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 82s 115ms/step - accuracy: 0.9826 - loss: 0.0533 - val_accuracy: 0.9443 - val_loss: 0.1760
# Epoch 8/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9824 - loss: 0.0509 - val_accuracy: 0.9386 - val_loss: 0.1860
# Epoch 9/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 57s 115ms/step - accuracy: 0.9829 - loss: 0.0565 - val_accuracy: 0.9561 - val_loss: 0.1493
# Epoch 10/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.9847 - loss: 0.0518 - val_accuracy: 0.9389 - val_loss: 0.2047

# %%
val_loss, val_accuracy = transfer_model.evaluate(val_dataset)
formatted_accuracy = "{:.2%}".format(val_accuracy)

print("Accuracy on validation set after transfer learning:", formatted_accuracy)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.9380 - loss: 0.1960
# Accuracy on validation set after transfer learning: 93.89%

# %% [markdown]
# ## 2.3 Hyperparameter Tuning

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
# Out:
# 2024-03-17 09:40:57.935174: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 09:40:57.935289: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 09:40:58.208868: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_images_kaggle():
    images = []
    labels = []

    root_path = '/kaggle/input/hg14-handgesture14-dataset/HG14/'

    for label in range(14):  
        gesture_folder = f'Gesture_{label}'
        gesture_path = os.path.join(root_path, 'HG14-Hand Gesture', gesture_folder)
        
        for dirname, _, filenames in os.walk(gesture_path):
            for filename in filenames:
                if filename.endswith('.jpg'):  
                    filepath = os.path.join(dirname, filename)
                    images.append(filepath)
                    labels.append(label)

    data = pd.DataFrame({'Image': images, 'Label': labels})
    return data

# %%
data = load_images_kaggle()

# %%
train_df, val_df = train_test_split(data, test_size=0.2, random_state=2024)

# %%
def preprocess_image(image):
    image = tf.image.resize(image, (224, 224))  
    image = tf.keras.applications.resnet50.preprocess_input(image)
    return image

# %%
def create_dataset(df, batch_size=32):
    image_paths = df['Image'].values
    labels = df['Label'].values

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(lambda x, y: (tf.io.read_file(x), y))

    def decode_and_preprocess_image(image, label):
        image = tf.image.decode_jpeg(image, channels=3)
        image = preprocess_image(image)
        return image, label
    
    dataset = dataset.map(decode_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
batch_size = 32
train_dataset = create_dataset(train_df, batch_size=batch_size)
val_dataset = create_dataset(val_df, batch_size=batch_size)

# %%
resnet50_base = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
for layer in resnet50_base.layers:
    layer.trainable = False

# %%
def hyperparameter_tuning(optimizers, learning_rates):
    best_accuracy = 0.0
    best_lr = None
    best_optimizer = None

    for optimizer in optimizers:
        for lr in learning_rates:
            transfer_model = models.Sequential([
                resnet50_base,
                layers.GlobalAveragePooling2D(),
                layers.Dense(512, activation='relu'),
                layers.Dense(14, activation='softmax')
            ])

            transfer_model.compile(optimizer=optimizer(learning_rate=lr),
                                   loss='sparse_categorical_crossentropy',
                                   metrics=['accuracy'])

            history = transfer_model.fit(train_dataset, epochs=10, validation_data=val_dataset, verbose=0)

            val_loss, val_accuracy = transfer_model.evaluate(val_dataset)

            print(f"Learning Rate: {lr}, Optimizer: {optimizer.__name__}, Accuracy: {val_accuracy * 100:.2f}%")

            if val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_lr = lr
                best_optimizer = optimizer.__name__

    print(f"Best LR: {best_lr}, Best Optimizer: {best_optimizer}, Best Accuracy: {best_accuracy * 100:.2f}%")

optimizers = [tf.keras.optimizers.Adam, tf.keras.optimizers.RMSprop]
learning_rates = [0.001, 0.0001]

hyperparameter_tuning(optimizers, learning_rates)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710668610.607359    1259 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710668610.664020    1259 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710668649.787745    1261 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710668662.392025    1259 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.9508 - loss: 0.1447
# Learning Rate: 0.001, Optimizer: Adam, Accuracy: 95.54%
# W0000 00:00:1710669210.716157    1258 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710669247.113945    1258 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710669256.129348    1260 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.9562 - loss: 0.1539
# Learning Rate: 0.0001, Optimizer: Adam, Accuracy: 95.39%
# W0000 00:00:1710669808.073178    1259 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710669845.052656    1261 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710669854.031145    1260 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.9465 - loss: 0.2021
# Learning Rate: 0.001, Optimizer: RMSprop, Accuracy: 94.82%
# W0000 00:00:1710670400.926181    1260 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710670437.387688    1260 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710670446.239274    1259 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.9533 - loss: 0.1488
# Learning Rate: 0.0001, Optimizer: RMSprop, Accuracy: 95.18%
# Best LR: 0.001, Best Optimizer: Adam, Best Accuracy: 95.54%

# %% [markdown]
# # 3. Comparing Accuracy of Models

# %%
from tabulate import tabulate

data = [
    ["Base ResNet-50 Model", 94.75],
    ["Data Augmentation", 82.29],
    ["Transfer Learning", 93.89],
    ["Hyperparameter Tuning", 95.54]
]

headers = ["Model", "Accuracy (%)"]

table = tabulate(data, headers=headers, tablefmt="github")
print(table)
# Out:
# | Model                 |   Accuracy (%) |
# |-----------------------|----------------|
# | Base ResNet-50 Model  |          94.75 |
# | Data Augmentation     |          82.29 |
# | Transfer Learning     |          93.89 |
# | Hyperparameter Tuning |          95.54 |

# %% [markdown]
# # 4. Evaluating Best Performing Model on Test Dataset

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def load_images_kaggle():
    images = []
    labels = []

    root_path = '/kaggle/input/hg14-handgesture14-dataset/HG14/'

    for label in range(14):  
        gesture_folder = f'Gesture_{label}'
        gesture_path = os.path.join(root_path, 'HG14-Hand Gesture', gesture_folder)
        
        for dirname, _, filenames in os.walk(gesture_path):
            for filename in filenames:
                if filename.endswith('.jpg'):  
                    filepath = os.path.join(dirname, filename)
                    images.append(filepath)
                    labels.append(label)

    data = pd.DataFrame({'Image': images, 'Label': labels})
    return data

data = load_images_kaggle()

# %%
train_val_df, test_df = train_test_split(data, test_size=0.2, random_state=2024)
train_df, val_df = train_test_split(train_val_df, test_size=0.2, random_state=2024)

# %%
def preprocess_image(image):
    image = tf.image.resize(image, (224, 224))  
    image = tf.keras.applications.resnet50.preprocess_input(image)
    return image

# %%
def create_dataset(df, batch_size=32):
    image_paths = df['Image'].values
    labels = df['Label'].values

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(lambda x, y: (tf.io.read_file(x), y))

    def decode_and_preprocess_image(image, label):
        image = tf.image.decode_jpeg(image, channels=3)
        image = preprocess_image(image)
        return image, label
    
    dataset = dataset.map(decode_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
batch_size = 32
train_dataset = create_dataset(train_val_df, batch_size=batch_size)
val_dataset = create_dataset(val_df, batch_size=batch_size)
test_dataset = create_dataset(test_df, batch_size=batch_size)

# %%
resnet50_base = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
for layer in resnet50_base.layers:
    layer.trainable = False

# %%
best_lr = 0.001
best_optimizer = tf.keras.optimizers.Adam(learning_rate=best_lr)

best_model = models.Sequential([
    resnet50_base,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dense(14, activation='softmax')
])

# %%
best_model.compile(optimizer=best_optimizer,
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
epochs = 10
best_model.fit(train_dataset, epochs=epochs, validation_data=val_dataset, verbose=1)
# Out:
# Epoch 1/10
#   1/350 ━━━━━━━━━━━━━━━━━━━━ 1:03:03 11s/step - accuracy: 0.0312 - loss: 3.6129
# W0000 00:00:1710693221.362587     160 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5338 - loss: 1.4619
# W0000 00:00:1710693254.088605     158 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 49s 110ms/step - accuracy: 0.5343 - loss: 1.4603 - val_accuracy: 0.9071 - val_loss: 0.3098
# Epoch 2/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.8956 - loss: 0.3171 - val_accuracy: 0.9460 - val_loss: 0.1725
# Epoch 3/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.9461 - loss: 0.1767 - val_accuracy: 0.9625 - val_loss: 0.1231
# Epoch 4/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.9621 - loss: 0.1218 - val_accuracy: 0.9812 - val_loss: 0.0691
# Epoch 5/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9688 - loss: 0.0968 - val_accuracy: 0.9714 - val_loss: 0.0797
# Epoch 6/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9656 - loss: 0.0971 - val_accuracy: 0.9759 - val_loss: 0.0717
# Epoch 7/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9697 - loss: 0.0826 - val_accuracy: 0.9719 - val_loss: 0.0756
# Epoch 8/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9770 - loss: 0.0645 - val_accuracy: 0.9723 - val_loss: 0.0740
# Epoch 9/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9796 - loss: 0.0620 - val_accuracy: 0.9513 - val_loss: 0.1329
# Epoch 10/10
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 34s 97ms/step - accuracy: 0.9797 - loss: 0.0648 - val_accuracy: 0.9830 - val_loss: 0.0426

# %%
test_loss, test_accuracy = best_model.evaluate(test_dataset)
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.9502 - loss: 0.1578
# W0000 00:00:1710693598.883404     159 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
y_true = np.concatenate([y for _, y in test_dataset], axis=0)
y_pred_probs = best_model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)

precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("Test Accuracy: {:.2f}%".format(test_accuracy * 100))
print("Test Precision: {:.4f}".format(precision))
print("Test Recall: {:.4f}".format(recall))
print("Test F1 Score: {:.4f}".format(f1))
# Out:
#  3/88 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step
# W0000 00:00:1710693610.624136     159 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 15s 120ms/step
# Test Accuracy: 94.75%
# Test Precision: 0.9492
# Test Recall: 0.9475
# Test F1 Score: 0.9472
# W0000 00:00:1710693621.098086     157 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
